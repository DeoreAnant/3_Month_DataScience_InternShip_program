# %% [markdown]
# Pandas **Lib**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/priceoye_laptops_version_2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0           0          Apple MacBook Air 13 M1 MGN63 (8GB-256GB)
# 1           1                 Apple Macbook Air 13 MW123 M4 Chip
# 2           2  ASUS Zenbook 14 UX3405CA Intel Core Ultra 7 25...
# 3           3  Lenovo ThinkPad E16 Gen 2 - Intel Core Ultra 7...
# 4           4          Lenovo IdeaPad Slim 3 Ryzen 7 (8GB-512GB)
#
#    Discounted Price  Actual Price   Saving  Rating  Reviews   Brand     Core  \
# 0          203499.0      258000.0  21% OFF     5.0      2.0   Apple       M1
# 1          281999.0      350000.0  19% OFF     4.3      5.0   Apple       M4
# 2          285999.0      330000.0  13% OFF     NaN      NaN    ASUS  Ultra 7
# 3          287999.0      340000.0  15% OFF     NaN      NaN  Lenovo  Ultra 7
# 4          146999.0      175000.0  16% OFF     NaN      NaN  Lenovo  Ryzen 7
#
#               SSD                                        Model
# ...

# %% [markdown]
# ## **Checked sum of all null values in each colomn**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Name                  0
# Discounted Price      0
# Actual Price         15
# Saving               15
# Rating              280
# Reviews             280
# Brand                 0
# Core                 87
# SSD                 214
# Model                 0
# dtype: int64

# %%
df['Actual Price'].isnull().sum()
# Out:
# np.int64(15)

# %%
df['Actual Price'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 301     True
# 302     True
# 303     True
# 304     True
# 305     True
# Name: Actual Price, Length: 306, dtype: bool

# %%
df['Actual Price'].fillna('unknown' ,inplace=True)
# Out:
# /tmp/ipython-input-607610158.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Actual Price'].fillna('unknown' ,inplace=True)
# /tmp/ipython-input-607610158.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Actual Price'].fillna('unknown' ,inplace=True)

# %%
df
# Out:
#      Unnamed: 0                                               Name  \
# 0             0          Apple MacBook Air 13 M1 MGN63 (8GB-256GB)
# 1             1                 Apple Macbook Air 13 MW123 M4 Chip
# 2             2  ASUS Zenbook 14 UX3405CA Intel Core Ultra 7 25...
# 3             3  Lenovo ThinkPad E16 Gen 2 - Intel Core Ultra 7...
# 4             4          Lenovo IdeaPad Slim 3 Ryzen 7 (8GB-512GB)
# ..          ...                                                ...
# 301         301  ASUS TUF FX507ZV4-LP349 12th Gen Core i7 (16GB...
# 302         302        Infinix GT BOOK Core i9 13900H (32GB - 1TB)
# 303         303  ASUS Expertbook B1500CBA 12th Gen Core i7 (16G...
# 304         304  ASUS TUF FX507ZC4-HN129 12th Gen Core i5 (8GB-...
# 305         305  Asus ROG Zephyrus G15 GA503QR 15.6 Inches Ryze...
#
#      Discounted Price Actual Price   Saving  Rating  Reviews    Brand  \
# 0            203499.0     258000.0  21% OFF     5.0      2.0    Apple
# ...

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(280)

# %%
df['Rating'].isnull()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 301     True
# 302     True
# 303     True
# 304     True
# 305     True
# Name: Rating, Length: 306, dtype: bool

# %%
df['Rating']=df['Rating'].fillna(2.5)

# %%
df
# Out:
#      Unnamed: 0                                               Name  \
# 0             0          Apple MacBook Air 13 M1 MGN63 (8GB-256GB)
# 1             1                 Apple Macbook Air 13 MW123 M4 Chip
# 2             2  ASUS Zenbook 14 UX3405CA Intel Core Ultra 7 25...
# 3             3  Lenovo ThinkPad E16 Gen 2 - Intel Core Ultra 7...
# 4             4          Lenovo IdeaPad Slim 3 Ryzen 7 (8GB-512GB)
# ..          ...                                                ...
# 301         301  ASUS TUF FX507ZV4-LP349 12th Gen Core i7 (16GB...
# 302         302        Infinix GT BOOK Core i9 13900H (32GB - 1TB)
# 303         303  ASUS Expertbook B1500CBA 12th Gen Core i7 (16G...
# 304         304  ASUS TUF FX507ZC4-HN129 12th Gen Core i5 (8GB-...
# 305         305  Asus ROG Zephyrus G15 GA503QR 15.6 Inches Ryze...
#
#      Discounted Price Actual Price   Saving  Rating  Reviews    Brand  \
# 0            203499.0     258000.0  21% OFF     5.0      2.0    Apple
# ...

# %%
df['Reviews'].isnull().sum()
# Out:
# np.int64(280)

# %%
df['Reviews'].isnull()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 301     True
# 302     True
# 303     True
# 304     True
# 305     True
# Name: Reviews, Length: 306, dtype: bool

# %%
df['Reviews']=df['Reviews'].fillna(0)
df
# Out:
#      Unnamed: 0                                               Name  \
# 0             0          Apple MacBook Air 13 M1 MGN63 (8GB-256GB)
# 1             1                 Apple Macbook Air 13 MW123 M4 Chip
# 2             2  ASUS Zenbook 14 UX3405CA Intel Core Ultra 7 25...
# 3             3  Lenovo ThinkPad E16 Gen 2 - Intel Core Ultra 7...
# 4             4          Lenovo IdeaPad Slim 3 Ryzen 7 (8GB-512GB)
# ..          ...                                                ...
# 301         301  ASUS TUF FX507ZV4-LP349 12th Gen Core i7 (16GB...
# 302         302        Infinix GT BOOK Core i9 13900H (32GB - 1TB)
# 303         303  ASUS Expertbook B1500CBA 12th Gen Core i7 (16G...
# 304         304  ASUS TUF FX507ZC4-HN129 12th Gen Core i5 (8GB-...
# 305         305  Asus ROG Zephyrus G15 GA503QR 15.6 Inches Ryze...
#
#      Discounted Price Actual Price   Saving  Rating  Reviews    Brand  \
# 0            203499.0     258000.0  21% OFF     5.0      2.0    Apple
# ...

# %%
df['SSD'].isnull().sum()
# Out:
# np.int64(214)

# %%
df['SSD'].isnull()
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 301     True
# 302     True
# 303     True
# 304     True
# 305     True
# Name: SSD, Length: 306, dtype: bool

# %%
df['SSD'].fillna('Unkonwn' , inplace=True)
df
# Out:
# /tmp/ipython-input-2102644896.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SSD'].fillna('Unkonwn' , inplace=True)
#      Unnamed: 0                                               Name  \
# 0             0          Apple MacBook Air 13 M1 MGN63 (8GB-256GB)
# 1             1                 Apple Macbook Air 13 MW123 M4 Chip
# 2             2  ASUS Zenbook 14 UX3405CA Intel Core Ultra 7 25...
# 3             3  Lenovo ThinkPad E16 Gen 2 - Intel Core Ultra 7...
# ...

# %%
df['Core'].isnull().sum()
# Out:
# np.int64(87)

# %%
df['Core'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 301    False
# 302    False
# 303    False
# 304    False
# 305    False
# Name: Core, Length: 306, dtype: bool

# %%
df['Core'].fillna('Unknown' ,inplace=True)
df
# Out:
# /tmp/ipython-input-4181428822.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Core'].fillna('Unknown' ,inplace=True)
#      Unnamed: 0                                               Name  \
# 0             0          Apple MacBook Air 13 M1 MGN63 (8GB-256GB)
# 1             1                 Apple Macbook Air 13 MW123 M4 Chip
# 2             2  ASUS Zenbook 14 UX3405CA Intel Core Ultra 7 25...
# 3             3  Lenovo ThinkPad E16 Gen 2 - Intel Core Ultra 7...
# ...

# %% [markdown]
# ## **Checked all null values are replaced or not**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Discounted Price     0
# Actual Price         0
# Saving              15
# Rating               0
# Reviews              0
# Brand                0
# Core                 0
# SSD                  0
# Model                0
# dtype: int64
