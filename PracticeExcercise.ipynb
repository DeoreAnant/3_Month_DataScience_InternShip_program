# %% [markdown]
# <a href="https://colab.research.google.com/github/DeoreAnant/3_Month_DataScience_InternShip_program/blob/main/PracticeExcercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Anant Deore")
# Out:
# Anant Deore
