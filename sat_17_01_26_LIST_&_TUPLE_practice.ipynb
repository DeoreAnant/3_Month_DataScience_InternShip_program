# %% [markdown]
# **List Function**

# %%
s =[2,3,4,5,3,1,3]
len(s)
# Out:
# 7

# %%
max(s)
# Out:
# 5

# %%
min(s)
# Out:
# 1

# %%
sum(s)
# Out:
# 21

# %%
sr=" hii Anant"
list(sr)
# Out:
# [' ', 'h', 'i', 'i', ' ', 'A', 'n', 'a', 'n', 't']

# %%
sorted(s)
# Out:
# [1, 2, 3, 3, 3, 4, 5]

# %%
s.append(50)
s
# Out:
# [2, 3, 4, 5, 3, 1, 3, 50]

# %%
s.remove(50)
s
# Out:
# [2, 3, 4, 5, 3, 1, 3]

# %%
s.sort()
s
# Out:
# [1, 2, 3, 3, 3, 4, 5]

# %%
s.reverse()
s
# Out:
# [5, 4, 3, 3, 3, 2, 1]

# %%
s.count(3)
# Out:
# 3

# %%
s.index(3)
# Out:
# 2

# %%
s.insert(0,500)
s
# Out:
# [500, 5, 4, 3, 3, 3, 2, 1]

# %%
s.pop(0)
# Out:
# 500

# %%
s.clear()

# %%
s
# Out:
# []

# %% [markdown]
# **Tuple Function**

# %%
s=(5,3,323,43,4,13,1,2)
len(s)
# Out:
# 8

# %%
max(s)
# Out:
# 323

# %%
min(s)
# Out:
# 1

# %%
sum(s)
# Out:
# 394

# %%
str="hello sir"
tup=tuple(str)
print(tup)
# Out:
# ('h', 'e', 'l', 'l', 'o', ' ', 's', 'i', 'r')

# %%
tup.count("l")
# Out:
# 2

# %%
print(len(tup))
tup.index('r')
# Out:
# 9
# 8

# %%
print(sorted(s))
# Out:
# [1, 2, 3, 4, 5, 13, 43, 323]
